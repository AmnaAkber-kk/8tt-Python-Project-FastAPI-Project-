# %%
import os
print(os.getcwd())
# Out:
# C:\Users\s tech

# %%
# %pip install fastapi uvicorn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%writefile FastApi.py

from fastapi import FastAPI

app = FastAPI()

@app.get("/")
def home():
    return {"message": "My FastAPI Project"}

@app.get("/Students")
def student():
    return {"name": "Ali", "age": 20, "course": "BSIT"}
# Out:
# Overwriting FastApi.py
